% %%
%ex6()
ex6_spam()
%submit()
% Out:
% == Submitting solutions | Support Vector Machines...
% Login (email address):viola.lewis@gmail.com
% Token:FA74W9ZaO6wsDG1e
% --------------------------------------------------------------------------------
% start searching best [C, sigma] values
% Train and evaluate (on cross validation set) for
% [_C, _sigma] = [0.010000 0.010000]
%
% Training ..................................... Done!
%
% prediction error: 0.565000
% error_min updated!
% [C, sigma] = [0.010000 0.010000]
% --------
% Train and evaluate (on cross validation set) for
% [_C, _sigma] = [0.010000 0.030000]
%
% Training ................................................ Done!
%
% prediction error: 0.060000
% error_min updated!
% [C, sigma] = [0.010000 0.030000]
% --------
% Train and evaluate (on cross validation set) for
% [_C, _sigma] = [0.010000 0.100000]
%
% Training .............................................. Done!
%
% prediction error: 0.045000
% error_min updated!
% [C, sigma] = [0.010000 0.100000]
% --------
% ...
